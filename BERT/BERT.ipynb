# %%
# !git clone https://github.com/TharunSivamani/Transformers.git
# %cd Transformers/BERT/
# Out:
# Cloning into 'Transformers'...
# remote: Enumerating objects: 29, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 29 (delta 3), reused 25 (delta 2), pack-reused 0
# Receiving objects: 100% (29/29), 1.94 MiB | 10.49 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /content/Transformers/BERT

# %%
from main import *
# Out:
# loading text...
# tokenizing sentences...
# creating/loading vocab...
# creating dataset...
# initializing model...
# initializing optimizer and loss...
# training...
# it: 0  | loss 10.28  | Δw: 1.329
# it: 10  | loss 9.59  | Δw: 0.633
# it: 20  | loss 9.36  | Δw: 0.411
# it: 30  | loss 9.24  | Δw: 0.339
# it: 40  | loss 9.03  | Δw: 0.275
# it: 50  | loss 8.91  | Δw: 0.254
# it: 60  | loss 8.77  | Δw: 0.221
# it: 70  | loss 8.6  | Δw: 0.219
# it: 80  | loss 8.42  | Δw: 0.202
# it: 90  | loss 8.28  | Δw: 0.192
# it: 100  | loss 8.14  | Δw: 0.182
# it: 110  | loss 7.96  | Δw: 0.176
# it: 120  | loss 7.83  | Δw: 0.164
# it: 130  | loss 7.71  | Δw: 0.161
# it: 140  | loss 7.58  | Δw: 0.156
# it: 150  | loss 7.49  | Δw: 0.15
# it: 160  | loss 7.36  | Δw: 0.151
# it: 170  | loss 7.17  | Δw: 0.16
# it: 180  | loss 7.12  | Δw: 0.145
# it: 190  | loss 7.03  | Δw: 0.148
# it: 200  | loss 6.96  | Δw: 0.139
# it: 210  | loss 6.87  | Δw: 0.141
# it: 220  | loss 6.81  | Δw: 0.142
# ...
