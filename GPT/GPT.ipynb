# %%
# !git clone https://github.com/TharunSivamani/Transformers.git
# %cd Transformers/GPT/
# Out:
# Cloning into 'Transformers'...
# remote: Enumerating objects: 54, done.
# remote: Counting objects: 100% (54/54), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 54 (delta 6), reused 50 (delta 5), pack-reused 0
# Receiving objects: 100% (54/54), 2.00 MiB | 20.04 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# /content/Transformers/GPT

# %%
# !pip install transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 35.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 65.3 MB/s eta 0:00:00
# ...

# %%
from main import *
# Out:
# Starting....
# ...
# Token indices sequence length is longer than the specified maximum sequence length for this model (37443 > 512). Running this sequence through the model will result in indexing errors
# Model with 89.48M parameters
# step          0 | train loss 10.7244 | val loss 10.7198
# step        500 | train loss 0.5055 | val loss 7.9601
# step       1000 | train loss 0.1613 | val loss 9.6467
# step       1500 | train loss 0.1275 | val loss 10.1915
# step       2000 | train loss 0.1284 | val loss 10.2829
# step       2500 | train loss 0.1179 | val loss 10.8537
# step       3000 | train loss 0.1208 | val loss 10.9433
# step       3500 | train loss 0.1235 | val loss 11.1779
# step       4000 | train loss 0.1098 | val loss 11.0326
# step       4500 | train loss 0.1142 | val loss 11.2541
# step       4999 | train loss 0.1065 | val loss 11.3750
# Validation....
# ...
