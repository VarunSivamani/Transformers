# %%
# !git clone https://github.com/TharunSivamani/Transformers.git
# %cd Transformers/ViT/
# Out:
# Cloning into 'Transformers'...
# remote: Enumerating objects: 410, done.
# remote: Counting objects: 100% (410/410), done.
# remote: Compressing objects: 100% (382/382), done.
# remote: Total 410 (delta 29), reused 395 (delta 17), pack-reused 0
# Receiving objects: 100% (410/410), 17.00 MiB | 15.88 MiB/s, done.
# Resolving deltas: 100% (29/29), done.
# /content/Transformers/ViT

# %%
from main import *

# %%
runner(pretrained = False)
# Out:
#   0%|          | 0/2 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 4.6171 | train_acc: 0.2617 | test_loss: 3.5231 | test_acc: 0.2604
# Epoch: 2 | train_loss: 1.9432 | train_acc: 0.2617 | test_loss: 1.3294 | test_acc: 0.5417

# %%
runner(pretrained = True)
# Out:
# Downloading: "https://download.pytorch.org/models/vit_b_16-c867db91.pth" to /root/.cache/torch/hub/checkpoints/vit_b_16-c867db91.pth
# 100%|██████████| 330M/330M [00:01<00:00, 201MB/s]
#   0%|          | 0/3 [00:00<?, ?it/s]
# Epoch: 1 | train_loss: 0.7067 | train_acc: 0.8008 | test_loss: 0.4524 | test_acc: 0.9280
# Epoch: 2 | train_loss: 0.3038 | train_acc: 0.9570 | test_loss: 0.2942 | test_acc: 0.9280
# Epoch: 3 | train_loss: 0.2142 | train_acc: 0.9648 | test_loss: 0.2219 | test_acc: 0.9176
#
# [INFO] Saving model to: models/08_pretrained_vit_feature_extractor_pizza_steak_sushi.pth
# Pretrained ViT feature extractor model size: 327 MB
